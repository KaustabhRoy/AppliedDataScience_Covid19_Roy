# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
pd.set_option('display.max_columns',500)

# %% [markdown]
# # Data Gathering

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv'

# %%
raw_data = pd.read_csv(url)

# %%
raw_data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 203791      ZWE    Africa     Zimbabwe  2022-07-21     256217.0       30.0
# 203792      ZWE    Africa     Zimbabwe  2022-07-22     256217.0        0.0
# 203793      ZWE    Africa     Zimbabwe  2022-07-23     256246.0       29.0
# 203794      ZWE    Africa     Zimbabwe  2022-07-24     256254.0        8.0
# 203795      ZWE    Africa     Zimbabwe  2022-07-25     256270.0       16.0
#
# ...

# %%
raw_data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.125                  0.125
# ...

# %%
raw_data.columns[:]
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# # Data Preparation

# %%
raw_data_base = raw_data.drop(['iso_code', 'continent', 'new_cases',
       'new_cases_smoothed', 'total_deaths', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients',
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'positive_rate', 'tests_per_case', 'tests_units', 'total_boosters',
       'new_vaccinations', 'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
       'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index',
       'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
       'excess_mortality', 'excess_mortality_cumulative_per_million'],axis = 1)

# %%
raw_data_base.head()
# Out:
#       location        date  total_cases  total_vaccinations  \
# 0  Afghanistan  2020-02-24          5.0                 NaN
# 1  Afghanistan  2020-02-25          5.0                 NaN
# 2  Afghanistan  2020-02-26          5.0                 NaN
# 3  Afghanistan  2020-02-27          5.0                 NaN
# 4  Afghanistan  2020-02-28          5.0                 NaN
#
#    people_vaccinated  people_fully_vaccinated  population
# 0                NaN                      NaN  40099462.0
# 1                NaN                      NaN  40099462.0
# 2                NaN                      NaN  40099462.0
# 3                NaN                      NaN  40099462.0
# 4                NaN                      NaN  40099462.0

# %%
raw_data_base = raw_data_base.rename(columns = {'location':'Country'})
#raw_data_base['people_fully_vaccinated'] = raw_data_base['people_fully_vaccinated'].dropna()
raw_data_base
# Out:
#             Country        date  total_cases  total_vaccinations  \
# 0       Afghanistan  2020-02-24          5.0                 NaN
# 1       Afghanistan  2020-02-25          5.0                 NaN
# 2       Afghanistan  2020-02-26          5.0                 NaN
# 3       Afghanistan  2020-02-27          5.0                 NaN
# 4       Afghanistan  2020-02-28          5.0                 NaN
# ...             ...         ...          ...                 ...
# 203791     Zimbabwe  2022-07-21     256217.0                 NaN
# 203792     Zimbabwe  2022-07-22     256217.0                 NaN
# 203793     Zimbabwe  2022-07-23     256246.0                 NaN
# 203794     Zimbabwe  2022-07-24     256254.0                 NaN
# 203795     Zimbabwe  2022-07-25     256270.0                 NaN
#
#         people_vaccinated  people_fully_vaccinated  population
# 0                     NaN                      NaN  40099462.0
# ...

# %%
raw_data_base['Country']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 203791       Zimbabwe
# 203792       Zimbabwe
# 203793       Zimbabwe
# 203794       Zimbabwe
# 203795       Zimbabwe
# Name: Country, Length: 203796, dtype: object

# %%
raw_data_india = raw_data_base[raw_data_base['Country']=='India']
raw_data_spain = raw_data_base[raw_data_base['Country']=='Spain']
raw_data_germany = raw_data_base[raw_data_base['Country']=='Germany']
raw_data_usa = raw_data_base[raw_data_base['Country']=='United States']
raw_data_france = raw_data_base[raw_data_base['Country']=='France']

# %%
absolute_cases = raw_data_base['total_cases']
population = raw_data_base['population']
vaccinated_population = raw_data_base['people_fully_vaccinated']
date = raw_data_base['date']

# %%
Covid_infectors = absolute_cases/population*100
Vaccination_percentage = vaccinated_population/population*100

# %%
Covid_infectors
# Out:
# 0         0.000012
# 1         0.000012
# 2         0.000012
# 3         0.000012
# 4         0.000012
#             ...
# 203791    1.602005
# 203792    1.602005
# 203793    1.602186
# 203794    1.602236
# 203795    1.602336
# Length: 203796, dtype: float64

# %%
Vaccination_percentage
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 203791   NaN
# 203792   NaN
# 203793   NaN
# 203794   NaN
# 203795   NaN
# Length: 203796, dtype: float64

# %%
raw_data_base['Infected_Population'] = (Covid_infectors)
raw_data_refined = raw_data_base.rename(columns = {'date':'Date'})

# %%
raw_data_base
# Out:
#             Country        date  total_cases  total_vaccinations  \
# 0       Afghanistan  2020-02-24          5.0                 NaN
# 1       Afghanistan  2020-02-25          5.0                 NaN
# 2       Afghanistan  2020-02-26          5.0                 NaN
# 3       Afghanistan  2020-02-27          5.0                 NaN
# 4       Afghanistan  2020-02-28          5.0                 NaN
# ...             ...         ...          ...                 ...
# 203791     Zimbabwe  2022-07-21     256217.0                 NaN
# 203792     Zimbabwe  2022-07-22     256217.0                 NaN
# 203793     Zimbabwe  2022-07-23     256246.0                 NaN
# 203794     Zimbabwe  2022-07-24     256254.0                 NaN
# 203795     Zimbabwe  2022-07-25     256270.0                 NaN
#
#         people_vaccinated  people_fully_vaccinated  population  \
# 0                     NaN                      NaN  40099462.0
# ...

# %%
Date = raw_data_base['date']
Country = raw_data_base['Country']
raw_data_base_vaccinations = pd.DataFrame({'Date':date,'Country':Country,'Vaccinated_Population':(Vaccination_percentage)})

# %%
raw_data_base_vaccinations_complete = raw_data_base_vaccinations.dropna()

# %%
country_list = ['Germany','India','Spain']

# %%
data_india = raw_data_refined['Country']=='India'
data_germany = raw_data_refined['Country']=='Germany'
data_spain = raw_data_refined['Country']=='Spain'

# %%
country_data_list = data_india|data_germany|data_spain

# %%
country_infection_data = raw_data_refined[country_data_list]
country_vaccination_data = raw_data_base_vaccinations_complete[country_data_list]
# Out:
# <ipython-input-64-ab2d5c29c3cb>:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
country_infection_data
# Out:
#         Country        Date  total_cases  total_vaccinations  \
# 68727   Germany  2020-01-27          1.0                 NaN
# 68728   Germany  2020-01-28          4.0                 NaN
# 68729   Germany  2020-01-29          4.0                 NaN
# 68730   Germany  2020-01-30          4.0                 NaN
# 68731   Germany  2020-01-31          5.0                 NaN
# ...         ...         ...          ...                 ...
# 173179    Spain  2022-07-21   13132159.0                 NaN
# 173180    Spain  2022-07-22   13204863.0                 NaN
# 173181    Spain  2022-07-23   13204863.0                 NaN
# 173182    Spain  2022-07-24   13204863.0                 NaN
# 173183    Spain  2022-07-25   13204863.0                 NaN
#
#         people_vaccinated  people_fully_vaccinated  population  \
# 68727                 NaN                      NaN  83408554.0
# 68728                 NaN                      NaN  83408554.0
# ...

# %% [markdown]
# # Plot figures for data visualisation

# %%
import plotly.express as px
fig = px.line(country_infection_data, x = "Date", y="Infected_Population", color='Country', title = 'Infected population percent over time')
fig.show()
# Out:
# <div>                            <div id="5f24a982-b3b9-48ae-9eda-50b0d4ed79af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f24a982-b3b9-48ae-9eda-50b0d4ed79af")) {                    Plotly.newPlot(                        "5f24a982-b3b9-48ae-9eda-50b0d4ed79af",                        [{"hovertemplate":"Country=Germany<br>Date=%{x}<br>Infected_Population=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020
# ...

# %%
fig = px.line(country_vaccination_data, x = "Date", y = "Vaccinated_Population",color = 'Country', title = 'Vaccinated population percent over time')
fig.show()
# Out:
# <div>                            <div id="11c3c831-8786-4b4d-b5db-d752c13be727" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11c3c831-8786-4b4d-b5db-d752c13be727")) {                    Plotly.newPlot(                        "11c3c831-8786-4b4d-b5db-d752c13be727",                        [{"hovertemplate":"Country=Germany<br>Date=%{x}<br>Vaccinated_Population=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2021-01-15","2021-01-16","2021-01-17","2021-01-18","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-23","2021-01-24","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-01-30","2021-01-31","20
# ...

# %% [markdown]
# # Dash Implementation

# %%
import dash
from dash import dcc
from dash import html


app = dash.Dash()
app.layout = html.Div([
    #dcc.Graph(figure = fig)
    html.Label('Multi-Select Country'),
    dcc.Dropdown(
        id = 'Country_Drop_Down',
        options = [
            {'label':'Germany', 'value':'Germany'},
            {'label':'India', 'value':'India'},
            {'label':'Spain', 'value':'Spain'}
        ],
        value= ['Germany','India'],
        multi = True
    ),
    dcc.Graph(figure = fig, id = 'main_window_slope')
])

# %%
from dash.dependencies import Input,Output

@app.callback(
    Output('main_window_slope','figure'),
    [Input('Country_Drop_Down','value')])

def update_figure(country_list):
    
    traces = []
    for each in country_list:
            traces.append(dict(x=country_infection_data.Date,
                                y=country_infection_data.Infected_Population,
                                mode = 'markers+lines',
                                opacity = 0.9,
                                line_width = 2,
                                marker_size = 4,
                                name = each))

            
    return {
        'data':traces,
        'layout':dict(
            width = 1600,
            height = 1200,
            xaxis_title='Time',
            yaxis_title='Confirmed infected people (Source: John Hopkins, log-scale)')

    }

# %%
app.run_server(debug = True, use_reloader = False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
